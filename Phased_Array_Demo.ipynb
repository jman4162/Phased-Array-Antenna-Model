# %% [markdown]
# # Phased Array Antenna Modeling - Comprehensive Demo
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jman4162/Phased-Array-Antenna-Model/blob/main/Phased_Array_Demo.ipynb)
#
# This notebook demonstrates all features of the `phased_array` package:
#
# 1. **Performance**: Vectorized array factor computation (50-100x faster)
# 2. **Array Geometries**: Rectangular, circular, conformal, sparse arrays
# 3. **Beamforming**: Amplitude tapering, null steering, multi-beam
# 4. **Impairments**: Mutual coupling, phase quantization, element failures
# 5. **Visualization**: 2D/3D plots, UV-space representation

# %%
# Install the package (needed on Colab; no-op if already installed)
# %pip install -q phased-array-modeling

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
import time

# Add package to path (for local development)
sys.path.insert(0, '.')

import phased_array as pa

print(f"phased_array version: {pa.__version__}")

# %% [markdown]
# ## 1. Basic Array Factor Computation
#
# Create a simple rectangular array and compute its radiation pattern.

# %%
# Create a 16x16 rectangular array with half-wavelength spacing
Nx, Ny = 16, 16
dx, dy = 0.5, 0.5  # wavelengths
wavelength = 1.0   # normalized

geom = pa.create_rectangular_array(Nx, Ny, dx, dy, wavelength)
print(f"Array has {geom.n_elements} elements")

# Wavenumber
k = pa.wavelength_to_k(wavelength)

# Uniform weights (broadside beam)
weights = np.ones(geom.n_elements, dtype=complex)

# Compute pattern
theta, phi, pattern_dB = pa.compute_full_pattern(
    geom.x, geom.y, weights, k,
    n_theta=91, n_phi=361
)

# Plot contour
pa.plot_pattern_contour(
    np.rad2deg(theta), np.rad2deg(phi), pattern_dB,
    title="16x16 Array - Broadside Beam"
)
plt.show()

# %% [markdown]
# ## 2. Beam Steering
#
# Steer the beam to different angles using phase shifts.

# %%
# Steer beam to theta=30 deg, phi=45 deg
theta0, phi0 = 30, 45  # degrees

weights_steered = pa.steering_vector(k, geom.x, geom.y, theta0, phi0)

# Compute pattern cuts
angles, E_plane, H_plane = pa.compute_pattern_cuts(
    geom.x, geom.y, weights_steered, k,
    theta0_deg=theta0, phi0_deg=phi0
)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

pa.plot_pattern_2d(angles, E_plane, title=f"E-Plane Cut (phi={phi0}deg)", ax=ax1)
pa.plot_pattern_2d(angles, H_plane, title=f"H-Plane Cut (phi={phi0+90}deg)", ax=ax2)

plt.tight_layout()
plt.show()

print(f"E-plane HPBW: {pa.compute_half_power_beamwidth(angles, E_plane):.2f} deg")
print(f"H-plane HPBW: {pa.compute_half_power_beamwidth(angles, H_plane):.2f} deg")

# %% [markdown]
# ## 3. Performance Comparison: Vectorized vs Loop
#
# Demonstrate the speedup of vectorized computation.

# %%
# Reference loop implementation (slow)
def array_factor_loop(theta, phi, x, y, weights, k):
    AF = np.zeros(theta.shape, dtype=complex)
    for i in range(len(x)):
        u = np.sin(theta) * np.cos(phi)
        v = np.sin(theta) * np.sin(phi)
        phase = k * (x[i] * u + y[i] * v)
        AF += weights[i] * np.exp(1j * phase)
    return AF

# Test grid
theta_test = np.linspace(0, np.pi/2, 91)
phi_test = np.linspace(0, 2*np.pi, 361)
theta_grid, phi_grid = np.meshgrid(theta_test, phi_test, indexing='ij')

# Time loop version
start = time.time()
AF_loop = array_factor_loop(theta_grid, phi_grid, geom.x, geom.y, weights_steered, k)
time_loop = time.time() - start

# Time vectorized version
start = time.time()
AF_vec = pa.array_factor_vectorized(theta_grid, phi_grid, geom.x, geom.y, weights_steered, k)
time_vec = time.time() - start

print(f"Loop time: {time_loop*1000:.1f} ms")
print(f"Vectorized time: {time_vec*1000:.1f} ms")
print(f"Speedup: {time_loop/time_vec:.1f}x")
print(f"Results match: {np.allclose(AF_loop, AF_vec)}")

# %% [markdown]
# ## 4. Amplitude Tapering for Sidelobe Control
#
# Apply various window functions to reduce sidelobes.

# %%
# Compare different tapers
tapers = {
    'Uniform': np.ones(geom.n_elements),
    'Taylor -25dB': pa.taylor_taper_2d(Nx, Ny, sidelobe_dB=-25),
    'Taylor -35dB': pa.taylor_taper_2d(Nx, Ny, sidelobe_dB=-35),
    'Chebyshev -30dB': pa.chebyshev_taper_2d(Nx, Ny, sidelobe_dB=-30),
    'Hamming': pa.hamming_taper_2d(Nx, Ny),
}

patterns = {}
for name, taper in tapers.items():
    weights_tapered = weights_steered * taper
    angles, E_plane, _ = pa.compute_pattern_cuts(
        geom.x, geom.y, weights_tapered, k,
        theta0_deg=theta0, phi0_deg=phi0
    )
    patterns[name] = E_plane
    
    # Print efficiency
    eff = pa.compute_taper_efficiency(taper)
    loss = pa.compute_taper_directivity_loss(taper)
    print(f"{name}: efficiency={eff:.1%}, loss={loss:.2f} dB")

pa.plot_comparison_patterns(angles, patterns, title="Taper Comparison")
plt.show()

# %% [markdown]
# ## 5. Array Geometries

# %%
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

# Rectangular
geom_rect = pa.create_rectangular_array(8, 8, 0.5, 0.5)
pa.plot_array_geometry(geom_rect, title=f"Rectangular ({geom_rect.n_elements} elements)", ax=axes[0,0])

# Triangular
geom_tri = pa.create_triangular_array(8, 8, 0.5)
pa.plot_array_geometry(geom_tri, title=f"Triangular ({geom_tri.n_elements} elements)", ax=axes[0,1])

# Circular
geom_circ = pa.create_circular_array(16, radius=2.0)
pa.plot_array_geometry(geom_circ, title=f"Circular Ring ({geom_circ.n_elements} elements)", ax=axes[0,2])

# Concentric rings
geom_rings = pa.create_concentric_rings_array(3, [8, 12, 16], ring_spacing=0.6)
pa.plot_array_geometry(geom_rings, title=f"Concentric Rings ({geom_rings.n_elements} elements)", ax=axes[1,0])

# Elliptical boundary
geom_ellip = pa.create_elliptical_array(a=3, b=2, dx=0.5, grid_type='rectangular')
pa.plot_array_geometry(geom_ellip, title=f"Elliptical ({geom_ellip.n_elements} elements)", ax=axes[1,1])

# Sparse/thinned
geom_sparse = pa.thin_array_random(geom_rect, thinning_factor=0.5, seed=42)
pa.plot_array_geometry(geom_sparse, title=f"50% Thinned ({geom_sparse.n_elements} elements)", ax=axes[1,2])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Null Steering
#
# Place nulls in specific directions to reject interference.

# %%
# Main beam at broadside, nulls at +/-20 degrees
null_directions = [(20, 0), (-20, 0), (15, 90)]  # (theta, phi) in degrees

weights_nulled = pa.null_steering_projection(
    geom, k,
    theta_main_deg=0, phi_main_deg=0,
    null_directions=null_directions
)

# Compute patterns
angles, pattern_uniform, _ = pa.compute_pattern_cuts(
    geom.x, geom.y, np.ones(geom.n_elements), k
)
_, pattern_nulled, _ = pa.compute_pattern_cuts(
    geom.x, geom.y, weights_nulled, k
)

pa.plot_comparison_patterns(
    angles,
    {'Uniform': pattern_uniform, 'With Nulls': pattern_nulled},
    title="Null Steering Comparison"
)

# Mark null positions
for theta_null, phi_null in null_directions:
    plt.axvline(theta_null, color='red', linestyle='--', alpha=0.5)
    plt.axvline(-theta_null, color='red', linestyle='--', alpha=0.5)

plt.show()

# Check null depths
for theta_null, phi_null in null_directions:
    depth = pa.compute_null_depth(weights_nulled, geom, k, theta_null, phi_null, 0, 0)
    print(f"Null at ({theta_null}, {phi_null}) deg: {depth:.1f} dB")

# %% [markdown]
# ## 7. Multiple Simultaneous Beams

# %%
# Create 3 simultaneous beams
beam_directions = [
    (0, 0),     # Broadside
    (25, 0),    # 25 deg in phi=0
    (25, 180),  # 25 deg in phi=180
]

weights_multi = pa.multi_beam_weights_superposition(
    geom, k, beam_directions,
    amplitudes=[1.0, 0.7, 0.7]  # Slightly lower for side beams
)

# Compute full pattern
theta_full, phi_full, pattern_multi = pa.compute_full_pattern(
    geom.x, geom.y, weights_multi, k,
    n_theta=91, n_phi=181,
    phi_range=(0, np.pi)  # Half-space
)

# Plot
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

angles, E_cut, _ = pa.compute_pattern_cuts(geom.x, geom.y, weights_multi, k)
pa.plot_pattern_2d(angles, E_cut, title="Multi-Beam Pattern (phi=0 cut)", ax=ax1)

pa.plot_pattern_contour(
    np.rad2deg(theta_full), np.rad2deg(phi_full), pattern_multi,
    title="Multi-Beam 2D Pattern", ax=ax2
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Phase Quantization Effects

# %%
# Compare different phase quantization levels
weights_ideal = pa.steering_vector(k, geom.x, geom.y, 30, 0)

patterns_quant = {}
for n_bits in [2, 3, 4, 6, 8]:
    weights_q = pa.quantize_phase(weights_ideal, n_bits)
    angles, E_plane, _ = pa.compute_pattern_cuts(geom.x, geom.y, weights_q, k, 30, 0)
    patterns_quant[f'{n_bits}-bit ({pa.quantization_rms_error(n_bits):.1f} deg RMS)'] = E_plane

# Add ideal
angles, E_ideal, _ = pa.compute_pattern_cuts(geom.x, geom.y, weights_ideal, k, 30, 0)
patterns_quant['Ideal'] = E_ideal

pa.plot_comparison_patterns(angles, patterns_quant, title="Phase Quantization Effects")
plt.show()

# %% [markdown]
# ## 9. Element Failures and Graceful Degradation

# %%
# Simulate different failure rates
failure_rates = [0, 0.05, 0.10, 0.20]
patterns_fail = {}

weights_nom = pa.steering_vector(k, geom.x, geom.y, 0, 0)
weights_nom *= pa.taylor_taper_2d(Nx, Ny, -30)  # With taper

for rate in failure_rates:
    if rate == 0:
        weights_deg = weights_nom
    else:
        weights_deg, failed = pa.simulate_element_failures(weights_nom, rate, mode='off', seed=42)
    
    angles, E_plane, _ = pa.compute_pattern_cuts(geom.x, geom.y, weights_deg, k)
    patterns_fail[f'{rate*100:.0f}% failures'] = E_plane

pa.plot_comparison_patterns(angles, patterns_fail, title="Element Failure Effects")
plt.show()

# %% [markdown]
# ## 10. UV-Space Visualization

# %%
# Compute pattern in UV-space
weights_scan = pa.steering_vector(k, geom.x, geom.y, 30, 45)
weights_scan *= pa.taylor_taper_2d(Nx, Ny, -30)

u, v, pattern_uv = pa.compute_pattern_uv_space(
    geom, weights_scan, k,
    n_u=201, n_v=201
)

pa.plot_pattern_uv_space(
    u, v, pattern_uv,
    title="Pattern in UV-Space (scan to 30deg, 45deg)",
    show_visible_region=True,
    show_grating_circles=True,
    dx_wavelengths=0.5,
    dy_wavelengths=0.5
)
plt.show()

# %% [markdown]
# ## 11. Interactive 3D Visualization (Plotly)

# %%
# 3D spherical pattern plot
theta_3d, phi_3d, pattern_3d = pa.compute_full_pattern(
    geom.x, geom.y, weights_scan, k,
    n_theta=61, n_phi=121
)

fig = pa.plot_pattern_3d_plotly(
    theta_3d, phi_3d, pattern_3d,
    title="3D Radiation Pattern",
    surface_type='spherical'
)
fig.show()

# %%
# Interactive array geometry
geom_cyl = pa.create_cylindrical_array(12, 5, radius=2, height=3)
weights_cyl = pa.steering_vector(k, geom_cyl.x, geom_cyl.y, 30, 0, geom_cyl.z)

fig = pa.plot_array_geometry_3d_plotly(
    geom_cyl, weights_cyl,
    title="Cylindrical Array Geometry",
    show_normals=True
)
fig.show()

# %% [markdown]
# ## 12. Conformal Array Pattern

# %%
# Create a hemispherical array
geom_sphere = pa.create_spherical_array(
    n_theta=6, n_phi=12,
    radius=5,
    theta_min=0.1, theta_max=np.pi/2
)

# Simple uniform weights
weights_sphere = np.ones(geom_sphere.n_elements, dtype=complex)

# Compute conformal array pattern (accounts for element orientations)
theta_grid, phi_grid = np.meshgrid(
    np.linspace(0, np.pi/2, 91),
    np.linspace(0, 2*np.pi, 181),
    indexing='ij'
)

AF_conformal = pa.array_factor_conformal(
    theta_grid, phi_grid,
    geom_sphere, weights_sphere, k
)

pattern_conf_dB = pa.linear_to_db(np.abs(AF_conformal)**2)
pattern_conf_dB -= np.max(pattern_conf_dB)

fig, ax = plt.subplots(figsize=(10, 8))
pa.plot_pattern_contour(
    np.rad2deg(theta_grid), np.rad2deg(phi_grid), pattern_conf_dB,
    title="Hemispherical Conformal Array Pattern",
    ax=ax
)
plt.show()

# %% [markdown]
# ## 13. Mutual Coupling Effects

# %%
# Small array for clearer coupling effects
geom_small = pa.create_rectangular_array(8, 8, 0.5, 0.5)
weights_small = pa.steering_vector(k, geom_small.x, geom_small.y, 0, 0)

# Compute coupling matrix
C = pa.mutual_coupling_matrix_theoretical(
    geom_small, k,
    coupling_model='sinc',
    coupling_coeff=0.3
)

# Apply coupling (without and with compensation)
weights_coupled = pa.apply_mutual_coupling(weights_small, C, mode='transmit')
weights_compensated = pa.apply_mutual_coupling(weights_small, C, mode='compensate')

# Compare patterns
angles, p_ideal, _ = pa.compute_pattern_cuts(geom_small.x, geom_small.y, weights_small, k)
_, p_coupled, _ = pa.compute_pattern_cuts(geom_small.x, geom_small.y, weights_coupled, k)
_, p_comp, _ = pa.compute_pattern_cuts(geom_small.x, geom_small.y, weights_compensated, k)

pa.plot_comparison_patterns(
    angles,
    {'Ideal': p_ideal, 'With Coupling': p_coupled, 'Compensated': p_comp},
    title="Mutual Coupling Effects"
)
plt.show()

# %% [markdown]
# ## 14. Subarray Beamforming

# %%
# Create 16x16 array divided into 4x4 subarrays
arch = pa.create_rectangular_subarrays(
    Nx_total=16, Ny_total=16,
    Nx_sub=4, Ny_sub=4,
    dx=0.5, dy=0.5
)

print(f"Total elements: {arch.geometry.n_elements}")
print(f"Number of subarrays: {arch.n_subarrays}")

# Compute subarray-level steering (quantized phase per subarray)
weights_sub = pa.compute_subarray_weights(
    arch, k,
    theta0_deg=20, phi0_deg=0
)

# Compare to element-level steering
weights_elem = pa.steering_vector(k, arch.geometry.x, arch.geometry.y, 20, 0)

angles, p_elem, _ = pa.compute_pattern_cuts(arch.geometry.x, arch.geometry.y, weights_elem, k, 20, 0)
_, p_sub, _ = pa.compute_pattern_cuts(arch.geometry.x, arch.geometry.y, weights_sub, k, 20, 0)

pa.plot_comparison_patterns(
    angles,
    {'Element-Level': p_elem, 'Subarray-Level': p_sub},
    title="Subarray vs Element-Level Beamforming"
)
plt.show()

# %% [markdown]
# ## 15. Wideband Arrays: True-Time Delay and Beam Squint
#
# Phase shifters set a fixed phase, but the phase needed to steer a beam scales with frequency. When a phase-steered array operates away from the frequency where its weights were computed, the beam points to `arcsin((f0/f) sin(theta0))` instead of `theta0` -- this pointing error is beam squint. True-time delay (TTD) elements apply a frequency-proportional phase (a constant delay), so the beam stays put across the band.
#
# Here: a 16x16 array at 10 GHz with 2 GHz bandwidth, steered to 45 degrees.

# %%
# 16x16 array at 10 GHz, half-wavelength spacing (positions in meters)
f0 = 10e9
c = 3e8
wavelength_wb = c / f0
geom_wb = pa.create_rectangular_array(16, 16, dx=0.5, dy=0.5, wavelength=wavelength_wb)

# 2 GHz bandwidth: 9 to 11 GHz
frequencies = np.linspace(f0 - 1e9, f0 + 1e9, 11)

squint_phase = pa.compute_beam_squint(
    geom_wb.x, geom_wb.y, theta0_deg=45, phi0_deg=0,
    center_frequency=f0, frequencies=frequencies, steering_mode='phase'
)
squint_ttd = pa.compute_beam_squint(
    geom_wb.x, geom_wb.y, theta0_deg=45, phi0_deg=0,
    center_frequency=f0, frequencies=frequencies, steering_mode='ttd'
)

print(f"Max squint, phase steering: {np.max(np.abs(squint_phase['squint'])):.2f} deg")
print(f"Max squint, TTD steering:   {np.max(np.abs(squint_ttd['squint'])):.2f} deg")

fig = pa.plot_beam_squint(frequencies, squint_phase, f0)
plt.show()

# %%
# Pattern cuts at the upper band edge (11 GHz):
# phase weights frozen at f0 vs TTD weights evaluated at the band edge
f_edge = f0 + 1e9
k0 = 2 * np.pi * f0 / c
k_edge = 2 * np.pi * f_edge / c

w_phase = pa.steering_vector(k0, geom_wb.x, geom_wb.y, 45, 0)          # set at 10 GHz
w_ttd = pa.steering_vector_ttd(geom_wb.x, geom_wb.y, 45, 0, frequency=f_edge)

angles_wb, E_phase, _ = pa.compute_pattern_cuts(geom_wb.x, geom_wb.y, w_phase, k_edge)
_, E_ttd, _ = pa.compute_pattern_cuts(geom_wb.x, geom_wb.y, w_ttd, k_edge)

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(angles_wb, E_phase, 'r-', label='Phase steering (weights set at 10 GHz)')
ax.plot(angles_wb, E_ttd, 'b--', label='TTD steering')
ax.axvline(45, color='gray', linestyle=':', label='Commanded 45 deg')
ax.set_xlabel('Theta (degrees)')
ax.set_ylabel('Normalized gain (dB)')
ax.set_xlim([20, 70])
ax.set_ylim([-40, 2])
ax.set_title('Pattern at 11 GHz band edge: phase vs TTD steering')
ax.grid(True, alpha=0.3)
ax.legend()
plt.show()

print(f"Phase-steered peak at {angles_wb[np.argmax(E_phase)]:.1f} deg "
      f"(squint {45 - angles_wb[np.argmax(E_phase)]:.1f} deg); "
      f"TTD peak at {angles_wb[np.argmax(E_ttd)]:.1f} deg")

# %% [markdown]
# ## 16. Beam Spoiling
#
# A quadratic phase profile across the aperture deliberately defocuses the beam, trading gain for beamwidth. Radars use spoiled beams in search modes to cover a sector with fewer dwells, then switch back to pencil beams for tracking. The broadened 3 dB beamwidth follows approximately `BW * sqrt(1 + spoil_factor^2)`.

# %%
geom_sp = pa.create_rectangular_array(16, 16, dx=0.5, dy=0.5)
k = pa.wavelength_to_k(1.0)

spoil_factor = 3.0
w_pencil = pa.steering_vector(k, geom_sp.x, geom_sp.y, 0, 0)
w_spoiled = pa.quadratic_phase_spoil(geom_sp, k, theta0_deg=0, phi0_deg=0,
                                     spoil_factor=spoil_factor)

angles_sp, E_pencil, _ = pa.compute_pattern_cuts(geom_sp.x, geom_sp.y, w_pencil, k)
_, E_spoiled, _ = pa.compute_pattern_cuts(geom_sp.x, geom_sp.y, w_spoiled, k)


def beamwidth_3dB(angles, E_dB):
    """Contiguous -3 dB width around the pattern peak."""
    i = np.argmax(E_dB)
    lo, hi = i, i
    while lo > 0 and E_dB[lo - 1] >= -3.0:
        lo -= 1
    while hi < len(E_dB) - 1 and E_dB[hi + 1] >= -3.0:
        hi += 1
    return angles[hi] - angles[lo]


bw_pencil = beamwidth_3dB(angles_sp, E_pencil)
bw_spoiled = beamwidth_3dB(angles_sp, E_spoiled)
bw_predicted = pa.spoiled_beamwidth(bw_pencil, spoil_factor)

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(angles_sp, E_pencil, 'b-', label=f'Pencil beam ({bw_pencil:.1f} deg)')
ax.plot(angles_sp, E_spoiled, 'r-', label=f'Spoiled, factor {spoil_factor} ({bw_spoiled:.1f} deg)')
ax.axhline(-3, color='gray', linestyle=':', alpha=0.7)
ax.set_xlabel('Theta (degrees)')
ax.set_ylabel('Normalized gain (dB)')
ax.set_ylim([-50, 2])
ax.set_title('Beam spoiling with quadratic phase')
ax.grid(True, alpha=0.3)
ax.legend()
plt.show()

print(f"Measured beamwidth ratio: {bw_spoiled / bw_pencil:.2f}x "
      f"(predicted {bw_predicted / bw_pencil:.2f}x)")

# Inverse problem: what spoil factor gives a 3x broader beam?
sf_needed = pa.compute_spoil_factor(geom_sp, desired_beamwidth_deg=3 * bw_pencil,
                                    unspoiled_beamwidth_deg=bw_pencil)
print(f"Spoil factor for 3x beamwidth: {sf_needed:.2f}")

# %% [markdown]
# ## 17. Overlapped Subarrays
#
# With one phase shifter per subarray, steering phase is quantized to the subarray centers. The resulting periodic phase error produces grating (quantization) lobes at `u = u0 +/- m*lambda/d_sub` for subarray pitch `d_sub`. Overlapping adjacent subarrays with amplitude-tapered shared elements smooths the effective subarray pattern, which suppresses these lobes without adding phase shifters.
#
# Here: a 16x16 array with 4x4 subarrays, contiguous (16 subarrays, 2-wavelength pitch) vs overlapped by 2 elements (49 subarrays, 1-wavelength pitch), both steered to 10 degrees at subarray level only.

# %%
k = pa.wavelength_to_k(1.0)
scan_deg = 10

# Contiguous 4x4 subarrays: 16 subarrays on a 2-wavelength pitch
arch_contig = pa.create_rectangular_subarrays(16, 16, Nx_sub=4, Ny_sub=4, dx=0.5, dy=0.5)

# Overlapped 4x4 subarrays sharing 2 elements with each neighbor
arch_over = pa.create_overlapped_subarrays(16, 16, Nx_sub=4, Ny_sub=4,
                                           overlap_x=2, overlap_y=2, dx=0.5, dy=0.5)
print(f"Contiguous: {arch_contig.n_subarrays} subarrays, "
      f"overlapped: {arch_over.n_subarrays} subarrays")

# Element weights (subarray-center phase only)
w_contig = pa.compute_subarray_weights(arch_contig, k, theta0_deg=scan_deg, phi0_deg=0)
w_over = pa.overlapped_subarray_weights(arch_over, k, theta0_deg=scan_deg, phi0_deg=0)

# Pattern cuts (compute_overlapped_pattern falls back to contiguous weights
# for a non-overlapped architecture)
th_sub, pat_contig = pa.compute_overlapped_pattern(arch_contig, k, scan_deg, 0)
_, pat_over = pa.compute_overlapped_pattern(arch_over, k, scan_deg, 0)

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(th_sub, pat_contig, 'r-', label='Contiguous subarrays')
ax.plot(th_sub, pat_over, 'b-', label='Overlapped subarrays')
ax.axvline(scan_deg, color='gray', linestyle=':', alpha=0.7)
ax.set_xlabel('Theta (degrees)')
ax.set_ylabel('Normalized gain (dB)')
ax.set_ylim([-40, 2])
ax.set_title(f'Subarray-level steering to {scan_deg} deg: grating lobe suppression')
ax.grid(True, alpha=0.3)
ax.legend()
plt.show()

# Grating lobe at u = sin(10 deg) + 0.5 -> ~43 deg for the 2-wavelength pitch
i_gl = np.argmin(np.abs(th_sub - 43))
print(f"Grating lobe near 43 deg: contiguous {pat_contig[i_gl]:.1f} dB, "
      f"overlapped {pat_over[i_gl]:.1f} dB "
      f"({pat_contig[i_gl] - pat_over[i_gl]:.1f} dB suppression)")

# %% [markdown]
# ## 18. Adaptive Beamforming (SMI)
#
# Sample Matrix Inversion computes MVDR weights `w = R^-1 s / (s^H R^-1 s)` from snapshots of interference-plus-noise data: the beamformer keeps unit gain on the desired direction while placing a null on whatever the covariance matrix says is loud. Diagonal loading regularizes the covariance estimate when snapshots are limited.
#
# Here: an 8x8 array with the desired signal at broadside and a 30 dB interferer at 20 degrees, in a sidelobe of the quiescent pattern.

# %%
geom_ad = pa.create_rectangular_array(8, 8, dx=0.5, dy=0.5)
k = pa.wavelength_to_k(1.0)
theta_int, phi_int = 20.0, 0.0
INR_dB = 30.0

# Simulate received snapshots: interferer plane wave + unit-power noise.
# Received-array manifold is the conjugate of the transmit steering vector.
rng = np.random.default_rng(42)
n_snapshots = 200
s_int = pa.steering_vector(k, geom_ad.x, geom_ad.y, theta_int, phi_int).conj()
amp = 10 ** (INR_dB / 20)
jam = amp * (rng.standard_normal((n_snapshots, 1))
             + 1j * rng.standard_normal((n_snapshots, 1))) / np.sqrt(2)
noise = (rng.standard_normal((n_snapshots, geom_ad.n_elements))
         + 1j * rng.standard_normal((n_snapshots, geom_ad.n_elements))) / np.sqrt(2)
snapshots = jam * s_int[None, :] + noise

w_quiescent = pa.steering_vector(k, geom_ad.x, geom_ad.y, 0, 0)
w_adapted = pa.adaptive_weights_smi(geom_ad, k, theta_desired_deg=0, phi_desired_deg=0,
                                    interference_data=snapshots, diagonal_loading=1e-2)

sinr_before, sinr_after, improvement = pa.compute_sinr_improvement(
    w_quiescent, w_adapted, geom_ad, k,
    signal_direction=(0, 0),
    interference_directions=[(theta_int, phi_int)],
    signal_power=1.0, interference_powers=[10 ** (INR_dB / 10)], noise_power=1.0
)
print(f"SINR before: {sinr_before:.1f} dB, after: {sinr_after:.1f} dB, "
      f"improvement: {improvement:.1f} dB")

ax = pa.plot_adapted_pattern(geom_ad, k, w_quiescent, w_adapted,
                             interference_directions=[(theta_int, phi_int)])
plt.show()

# %% [markdown]
# ## 19. Active Impedance and VSWR vs Scan
#
# When an array scans, each element sees coupled contributions from its neighbors, so its reflection coefficient depends on the excitation: `Gamma_active,n = sum_m C_nm w_m / w_n`. Active VSWR rises with scan angle and can spike at scan-blindness conditions, stressing T/R module output stages. This is why array front-ends are specified against active (scan) impedance, not isolated-element match.

# %%
geom_vs = pa.create_rectangular_array(8, 8, dx=0.5, dy=0.5)
k = pa.wavelength_to_k(1.0)

C = pa.mutual_coupling_matrix_theoretical(geom_vs, k, coupling_model='sinc',
                                          coupling_coeff=0.25)

theta_scan, vswr_all, vswr_max = pa.vswr_vs_scan(geom_vs, C, k,
                                                 theta_range=(0, 60), n_angles=31)

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(theta_scan, vswr_max, 'r-', linewidth=2, label='Worst element')
ax.plot(theta_scan, np.median(vswr_all, axis=1), 'b--', label='Median element')
ax.axhline(2.0, color='gray', linestyle=':', label='VSWR = 2 spec line')
ax.set_xlabel('Scan angle (degrees)')
ax.set_ylabel('Active VSWR')
ax.set_title('Active VSWR vs scan angle (E-plane)')
ax.grid(True, alpha=0.3)
ax.legend()
plt.show()

# Active reflection coefficient per element at 45 deg scan
w45 = pa.steering_vector(k, geom_vs.x, geom_vs.y, 45, 0)
gammas = np.array([pa.active_reflection_coefficient(C, w45, i)
                   for i in range(geom_vs.n_elements)])
worst = np.argmax(np.abs(gammas))
print(f"At 45 deg scan: worst element {worst} has |Gamma| = {np.abs(gammas[worst]):.3f} "
      f"(VSWR {(1 + np.abs(gammas[worst])) / (1 - np.abs(gammas[worst])):.2f})")

# %% [markdown]
# ## 20. Coordinate Transforms and Platform Rotation
#
# Antenna patterns live in theta/phi measured from boresight, while radar systems work in azimuth/elevation, and the platform itself may roll, pitch, and yaw. The `antenna_to_radar` / `radar_to_antenna` pair converts between angle conventions, and `rotate_pattern` re-grids a pattern through a roll-pitch-yaw rotation -- e.g. to see where an aircraft's beam actually points when the aircraft pitches up.

# %%
# Angle convention conversion (round trip)
az, el = pa.antenna_to_radar(np.deg2rad(30), np.deg2rad(0))
print(f"Antenna (theta=30, phi=0) -> radar az={np.rad2deg(az):.1f}, "
      f"el={np.rad2deg(el):.1f} deg")
th_back, ph_back = pa.radar_to_antenna(az, el)
print(f"Round trip: theta={np.rad2deg(th_back):.1f}, phi={np.rad2deg(ph_back):.1f} deg")

print("\n15-degree pitch rotation matrix:")
print(np.round(pa.rotation_matrix_pitch(np.deg2rad(15)), 4))

# %%
# Rotate an 8x8 broadside pattern for a platform pitched up 15 degrees
geom_rot = pa.create_rectangular_array(8, 8, dx=0.5, dy=0.5)
k = pa.wavelength_to_k(1.0)
w_rot = pa.steering_vector(k, geom_rot.x, geom_rot.y, 0, 0)

theta_1d, phi_1d, pattern_dB = pa.compute_full_pattern(
    geom_rot.x, geom_rot.y, w_rot, k, n_theta=91, n_phi=181)
theta_g, phi_g = np.meshgrid(theta_1d, phi_1d, indexing='ij')

theta_r, phi_r, pattern_rot = pa.rotate_pattern(
    theta_g, phi_g, pattern_dB, roll_deg=0, pitch_deg=15, yaw_deg=0)

fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)
for ax, pat, name in [(axes[0], pattern_dB, 'Antenna frame'),
                      (axes[1], pattern_rot, 'Platform pitched 15 deg')]:
    im = ax.pcolormesh(np.rad2deg(phi_g), np.rad2deg(theta_g),
                       np.clip(pat, -40, 0), cmap='viridis', shading='auto')
    ax.set_xlabel('Phi (degrees)')
    ax.set_title(name)
axes[0].set_ylabel('Theta (degrees)')
fig.colorbar(im, ax=axes, label='Gain (dB)')
plt.show()

i_peak = np.unravel_index(np.argmax(pattern_rot), pattern_rot.shape)
print(f"Rotated-frame peak at theta = {np.rad2deg(theta_g[i_peak]):.1f} deg "
      f"(was broadside before the pitch)")

# %% [markdown]
# ## 21. Polarization Math Primer
#
# Polarization states are described by Jones vectors `[Ex, Ey*exp(j*delta)]`, summarized by Stokes parameters, and characterized by axial ratio (AR = 1, or 0 dB, for circular; infinite for linear). The polarization loss factor `PLF = |j_ant . j_inc*|^2` gives the power coupling between an antenna and an incident wave: 1 for matched, 0.5 for linear-to-circular, 0 for orthogonal states.
#
# These utilities operate on polarization states directly; Section 22 applies them to full array patterns.

# %%
# Axial ratio and Stokes parameters for canonical states
states = {
    'Linear (H)':  pa.jones_vector(1.0, 0.0),
    'Linear (45)': pa.jones_vector(1.0, 1.0, phase_diff=0.0),
    'RHCP':        pa.jones_vector(1.0, 1.0, phase_diff=-np.pi / 2),
    'LHCP':        pa.jones_vector(1.0, 1.0, phase_diff=np.pi / 2),
    'Elliptical':  pa.jones_vector(1.0, 0.5, phase_diff=np.pi / 2),
}

print(f"{'State':<12} {'AR':>8} {'AR (dB)':>9}   Stokes (S0, S1, S2, S3)")
for name, jones in states.items():
    ar = pa.axial_ratio(jones)
    ar_dB = 20 * np.log10(ar) if np.isfinite(ar) else np.inf
    S = pa.stokes_parameters(jones)
    print(f"{name:<12} {ar:>8.2f} {ar_dB:>9.2f}   "
          f"({S[0]:.2f}, {S[1]:.2f}, {S[2]:.2f}, {S[3]:.2f})")

# %%
# Polarization loss factor between antenna/wave pairs
pairs = [
    ('H antenna, H wave', states['Linear (H)'], states['Linear (H)']),
    ('H antenna, V wave', states['Linear (H)'], pa.jones_vector(0.0, 1.0)),
    ('H antenna, 45-deg wave', states['Linear (H)'], states['Linear (45)']),
    ('H antenna, RHCP wave', states['Linear (H)'], states['RHCP']),
    ('RHCP antenna, RHCP wave', states['RHCP'], states['RHCP']),
    ('RHCP antenna, LHCP wave', states['RHCP'], states['LHCP']),
]

print(f"{'Configuration':<26} {'PLF':>6} {'Loss (dB)':>10}")
for name, j_ant, j_inc in pairs:
    plf = float(pa.polarization_loss_factor(j_ant, j_inc))
    loss_dB = -10 * np.log10(plf) if plf > 1e-12 else np.inf
    loss_str = f"{loss_dB:10.2f}" if np.isfinite(loss_dB) else "       inf"
    print(f"{name:<26} {plf:>6.3f} {loss_str}")

# %% [markdown]
# ## 22. Polarized Array Patterns (v1.4.0)
#
# The vector pattern engine carries full `(E_theta, E_phi)` fields through the array computation instead of a scalar gain, so cross-polarization, axial ratio, and conformal polarization effects come out of the same machinery. Element factories (`dipole_element`, `ideal_patch_element`, `crossed_dipole_element`, `cos_q_polarized_element`) supply polarized element patterns, and co/cross decomposition uses Ludwig's third definition.
#
# First: co- and cross-pol cuts of a 16x16 x-polarized array in the diagonal plane (phi = 45 deg), where Ludwig-3 cross-pol peaks. The ideal patch element has zero cross-pol by construction; the x-dipole shows the finite cross-pol of a real radiator.

# %%
geom_v = pa.create_rectangular_array(16, 16, dx=0.5, dy=0.5)
k = pa.wavelength_to_k(1.0)
w_v = pa.steering_vector(k, geom_v.x, geom_v.y, 0, 0)

th_cut, co_patch, cx_patch = pa.compute_co_cross_pattern_cuts(
    geom_v.x, geom_v.y, w_v, k,
    element_func=pa.ideal_patch_element('x'), phi_cut_deg=45)
_, co_dip, cx_dip = pa.compute_co_cross_pattern_cuts(
    geom_v.x, geom_v.y, w_v, k,
    element_func=pa.dipole_element('x'), phi_cut_deg=45)

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(th_cut, co_dip, 'b-', label='Co-pol (x-dipole)')
ax.plot(th_cut, cx_dip, 'b--', label='Cross-pol (x-dipole)')
ax.plot(th_cut, co_patch, 'r-', alpha=0.7, label='Co-pol (ideal patch)')
ax.plot(th_cut, cx_patch, 'r--', alpha=0.7, label='Cross-pol (ideal patch, floor)')
ax.set_xlabel('Theta (degrees)')
ax.set_ylabel('Normalized gain (dB)')
ax.set_ylim([-80, 5])
ax.set_title('Co/cross-pol cuts in the diagonal plane (phi = 45 deg, Ludwig-3)')
ax.grid(True, alpha=0.3)
ax.legend()
plt.show()

print(f"Max cross-pol, x-dipole elements:  {np.nanmax(cx_dip):.1f} dB")
print(f"Max cross-pol, ideal patch:        {np.nanmax(cx_patch):.1f} dB (numerical floor)")

# %%
# Crossed-dipole CP array: axial ratio over the forward hemisphere
w_bore = pa.steering_vector(k, geom_v.x, geom_v.y, 0, 0)
vp_cp = pa.compute_full_vector_pattern(
    geom_v.x, geom_v.y, w_bore, k,
    element_func=pa.crossed_dipole_element(-np.pi / 2),  # RHCP
    n_theta=91, n_phi=181)

ar_dB = 20 * np.log10(vp_cp.axial_ratio_map())

theta_1d = np.linspace(0, 90, 91)
phi_1d = np.linspace(0, 360, 181)
fig, ax = plt.subplots(figsize=(10, 5))
im = ax.pcolormesh(phi_1d, theta_1d, np.clip(ar_dB, 0, 20),
                   cmap='viridis_r', shading='auto')
fig.colorbar(im, ax=ax, label='Axial ratio (dB)')
ax.set_xlabel('Phi (degrees)')
ax.set_ylabel('Theta (degrees)')
ax.set_title('Axial ratio map, crossed-dipole RHCP array (broadside weights)')
plt.show()

# AR at boresight and at a 30 deg scanned beam peak
w_30 = pa.steering_vector(k, geom_v.x, geom_v.y, 30, 0)
vp_30 = pa.compute_full_vector_pattern(
    geom_v.x, geom_v.y, w_30, k,
    element_func=pa.crossed_dipole_element(-np.pi / 2),
    n_theta=91, n_phi=181)
ar_30_dB = 20 * np.log10(vp_30.axial_ratio_map())
i_30 = np.argmin(np.abs(theta_1d - 30))

print(f"Axial ratio at boresight:            {ar_dB[0, 0]:.2f} dB")
print(f"Axial ratio at 30 deg scanned peak:  {ar_30_dB[i_30, 0]:.2f} dB")

# %%
# Conformal polarization: cylindrical array, sector-excited, equatorial cut.
# Element local z = surface normal; local y maps to the cylinder axis, so
# dipole_element('y') gives vertical polarization (E_theta at the equator)
# and dipole_element('x') gives azimuthal polarization (E_phi).
geom_cyl = pa.create_cylindrical_array(n_azimuth=24, n_vertical=8,
                                       radius=2.0, height=4.0)

# Phase-conjugate weights toward (theta=90, phi=0); excite only the
# half-cylinder whose element normals face the beam
u0 = np.array([1.0, 0.0, 0.0])
r_el = np.stack([geom_cyl.x, geom_cyl.y, geom_cyl.z], axis=1)
normals = np.stack([geom_cyl.nx, geom_cyl.ny, geom_cyl.nz], axis=1)
w_cyl = np.exp(-1j * k * r_el @ u0) * (normals @ u0 > 0)

phi_cut = np.linspace(-np.pi / 2, np.pi / 2, 181)
theta_cut = np.full_like(phi_cut, np.pi / 2)

fig, ax = plt.subplots(figsize=(10, 5))
for ef, style, name in [(pa.dipole_element('y'), 'b', 'Axial dipoles (vertical pol)'),
                        (pa.dipole_element('x'), 'r', 'Azimuthal dipoles')]:
    E_th, E_ph = pa.vector_array_factor_conformal(
        theta_cut, phi_cut, geom_cyl, w_cyl, k, element_func=ef)
    P = np.abs(E_th) ** 2 + np.abs(E_ph) ** 2
    ax.plot(np.rad2deg(phi_cut), 10 * np.log10(P / P.max()), style + '-', label=name)
    frac_th = np.max(np.abs(E_th) ** 2) / P.max()
    print(f"{name}: E_theta carries {frac_th * 100:.1f}% of peak power "
          f"(E_phi {100 - frac_th * 100:.1f}%)")

ax.set_xlabel('Phi (degrees)')
ax.set_ylabel('Normalized gain (dB)')
ax.set_ylim([-40, 2])
ax.set_title('Cylindrical array, equatorial cut (theta = 90 deg)')
ax.grid(True, alpha=0.3)
ax.legend()
plt.show()

# %% [markdown]
# ## Summary
#
# This notebook demonstrated the key features of the `phased_array` package:
#
# 1. **50-100x speedup** with vectorized array factor computation
# 2. **Multiple array geometries**: rectangular, triangular, circular, conformal, sparse
# 3. **Amplitude tapering**: Taylor, Chebyshev, Hamming windows for sidelobe control
# 4. **Null steering**: projection and LCMV methods
# 5. **Multiple beams**: superposition and orthogonal beamforming
# 6. **Impairments**: mutual coupling, phase quantization, element failures
# 7. **Visualization**: 2D plots, UV-space, interactive 3D Plotly
# 8. **Wideband/TTD**: beam squint analysis and true-time-delay steering
# 9. **Beam spoiling**: quadratic-phase beam broadening for search modes
# 10. **Overlapped subarrays**: grating lobe suppression with shared elements
# 11. **Adaptive beamforming**: SMI/MVDR nulling with SINR metrics
# 12. **Active impedance**: scan-dependent VSWR from mutual coupling
# 13. **Coordinate transforms**: antenna/radar conventions and platform rotation
# 14. **Polarization**: Jones vectors, Stokes parameters, axial ratio, PLF
#
# 15. **Vector patterns (v1.4.0)**: polarized elements, co/cross-pol cuts, axial ratio maps, conformal vector fields
#
# For more details, see the docstrings in each module.
